# %%
import gcp.storage as storage
import gcp.bigquery as bq
from datetime import date
import pandas as pd
import numpy as np
from datetime import date
from datetime import timedelta
import os
import pdb
prev_n_range = 3

def calc_past_timeslot(timeslot, slots):
  timeslot_r = map(lambda x: int(x), timeslot.split('-'))
  slot = timeslot_r[3] - slots
  date_obj = date(timeslot_r[0], timeslot_r[1], timeslot_r[2])
  if slot <= 0:
    slot = 144
    date_obj = date_obj - timedelta(days=1)
  return '{}-{}-{}-{}'.format(
    date_obj.year, str(date_obj.month).zfill(2), str(date_obj.day).zfill(2), slot)

# %% [markdown]
# # Gaps Table Creation for Training
# First, here is an overview of `timeslot` field in **orders** table:

# %%
# %%sql --module q_timeslots
#
# SELECT FIRST(timeslot) AS timeslot
# FROM [datalab-projects-1331:xjk_algo_comp.orders] AS orders
# GROUP BY date, timeofday_slot
# ORDER BY date, timeofday_slot
#
# # Should be the same with GROUP BY timeslot

# %%
timeslots_df = bq.Query(q_timeslots).to_dataframe()
print('number of data points: {}'.format(len(timeslots_df)))
print('first 5:')
timeslots_df.head(5)
# Out:
# number of data points: 3024
# first 5:
#        timeslot
# 0  2016-01-01-1
# 1  2016-01-01-2
# 2  2016-01-01-3
# 3  2016-01-01-4
# 4  2016-01-01-5

# %%
print ('last 5:')
timeslots_df.tail(5)
# Out:
# last 5:
#             timeslot
# 3019  2016-01-21-140
# 3020  2016-01-21-141
# 3021  2016-01-21-142
# 3022  2016-01-21-143
# 3023  2016-01-21-144

# %% [markdown]
# In **orders** table, there are 3024 data points when grouped by `timeslot`. Since the data starts from date 2016-01-01, that means for a consecutive 21 days (until date 2016-01-21) all 144 timeslots in each day have orders.
#
# Therefore, we can use 3024 - `prev_n_range`(number of previous slots to use in prediction) data as our training data (for example, if we use 3 days for prediction, there are 3021 training data, starting from slot 2016-01-04, where we use data from 2016-01-01, 2016-01-02, and 2016-01-03 as features).

# %%
# Prepare columns for gaps table creation

pois_table = bq.Table('datalab-projects-1331:xjk_algo_comp.pois')
pois_fields = [item['name'] for item in pois_table.schema][1:]
traffic_fields = []
weather_fields = []
orders_fields = []
for i in range(prev_n_range):
  prev_n = i+1
  traffic_fields.append('tj_level1_{}_slots_ago'.format(prev_n))
  traffic_fields.append('tj_level2_{}_slots_ago'.format(prev_n))
  traffic_fields.append('tj_level3_{}_slots_ago'.format(prev_n))
  traffic_fields.append('tj_level4_{}_slots_ago'.format(prev_n))
  weather_fields.append('weather_{}_slots_ago'.format(prev_n))
  weather_fields.append('temperature_{}_slots_ago'.format(prev_n))
  weather_fields.append('pm25_{}_slots_ago'.format(prev_n))
  orders_fields.append('gap_{}_slots_ago'.format(prev_n))
  orders_fields.append('sum_price_{}_slots_ago'.format(prev_n))
columns = ['district_id', 'timeslot', 'day_in_week', 'timeofday_slot'] + \
  traffic_fields + weather_fields + orders_fields + pois_fields + ['gap']

# %% [markdown]
# First, get all timeslots to test.

# %%
all_timeslots = timeslots_df['timeslot'].tolist()[prev_n_range:]
tquery = ','.join(map(lambda x: "'{}'".format(x.strip()), all_timeslots))
print(tquery)
# Out:
# %% [markdown]
# Load all required data from previous timeslots from database.

# %% [markdown]
# ## Traffic

# %%
# %%sql --module q_traffic
# SELECT district_id, timeslot, tj_level1, tj_level2, tj_level3, tj_level4
# FROM xjk_algo_comp.traffic AS traffic
# JOIN xjk_algo_comp.districts AS districts
#   ON traffic.district_hash = districts.district_hash
# WHERE timeslot IN $timeslots

# %%
traffic_df = bq.Query(q_traffic, timeslots=prev_timeslots_flat).to_dataframe()

# %% [markdown]
# ## Weather

# %%
# %%sql --module q_weather
# SELECT * FROM xjk_algo_comp.weather
# WHERE timeslot IN $timeslots

# %%
weather_df = bq.Query(q_weather, timeslots=prev_timeslots_flat).to_dataframe()

# %% [markdown]
# ## Gaps from Orders

# %%
# %%sql --module q_order_gaps
#
# SELECT district_id, FIRST(orders.timeslot) AS timeslot, FIRST(orders.date) AS date,
#   FIRST(day_in_week) AS day_in_week, FIRST(timeofday_slot) AS timeofday_slot,
#   SUM(price) AS sum_price, AVG(price) AS avg_price,
#   IF(FIRST(timeofday_slot) >= 50 AND FIRST(timeofday_slot) <= 53, 1, 0) AS busy_time,
#   SUM(IF(driver_id = 'NULL', 1, 0)) AS gap
# FROM [datalab-projects-1331:xjk_algo_comp.orders] AS orders
# JOIN [datalab-projects-1331:xjk_algo_comp.districts] AS districts
#   ON orders.start_district_hash = districts.district_hash
# WHERE timeslot IN $timeslots
# GROUP BY district_id, orders.timeslot

# %%
order_gaps_df = bq.Query(q_order_gaps, timeslots=prev_timeslots_flat).to_dataframe()

# %% [markdown]
# ## POIs

# %%
text = ''
for counter, poi in enumerate(pois_fields):
  text += '{}, '.format(poi)
  if counter % 13 == 0 and counter > 0:
    text += '\n'
print text.strip()[:len(text.strip())-1]
# Out:
# f1, f11, f11_1, f11_2, f11_3, f11_4, f11_5, f11_6, f11_7, f11_8, f13_4, f13_8, f14, f14_1,
# f14_10, f14_2, f14_3, f14_6, f14_8, f15, f15_1, f15_2, f15_3, f15_4, f15_6, f15_7, f15_8,
# f16, f16_1, f16_10, f16_11, f16_12, f16_3, f16_4, f16_6, f17, f17_2, f17_3, f17_4, f17_5,
# f19, f19_1, f19_2, f19_3, f19_4, f1_1, f1_10, f1_11, f1_2, f1_3, f1_4, f1_5, f1_6,
# f1_7, f1_8, f20, f20_1, f20_2, f20_4, f20_5, f20_6, f20_7, f20_8, f20_9, f21_1, f21_2,
# f22, f22_1, f22_2, f22_3, f22_4, f22_5, f23, f23_1, f23_2, f23_3, f23_4, f23_5, f23_6,
# f24, f24_1, f24_2, f24_3, f25, f25_1, f25_3, f25_7, f25_8, f25_9, f2_1, f2_10, f2_11,
# f2_12, f2_13, f2_2, f2_4, f2_5, f2_6, f2_7, f2_8, f3_1, f3_2, f3_3, f4, f4_1,
# f4_10, f4_11, f4_13, f4_14, f4_16, f4_17, f4_18, f4_2, f4_3, f4_5, f4_6, f4_7, f4_8,
# f4_9, f5, f5_1, f5_3, f5_4, f6, f6_1, f6_2, f6_4, f7, f8, f8_1, f8_2,
# f8_3, f8_4, f8_5

# %%
# %%sql --module q_pois
# SELECT district_id,
# f1, f11, f11_1, f11_2, f11_3, f11_4, f11_5, f11_6, f11_7, f11_8, f13_4, f13_8, f14, f14_1,
# f14_10, f14_2, f14_3, f14_6, f14_8, f15, f15_1, f15_2, f15_3, f15_4, f15_6, f15_7, f15_8,
# f16, f16_1, f16_10, f16_11, f16_12, f16_3, f16_4, f16_6, f17, f17_2, f17_3, f17_4, f17_5,
# f19, f19_1, f19_2, f19_3, f19_4, f1_1, f1_10, f1_11, f1_2, f1_3, f1_4, f1_5, f1_6,
# f1_7, f1_8, f20, f20_1, f20_2, f20_4, f20_5, f20_6, f20_7, f20_8, f20_9, f21_1, f21_2,
# f22, f22_1, f22_2, f22_3, f22_4, f22_5, f23, f23_1, f23_2, f23_3, f23_4, f23_5, f23_6,
# f24, f24_1, f24_2, f24_3, f25, f25_1, f25_3, f25_7, f25_8, f25_9, f2_1, f2_10, f2_11,
# f2_12, f2_13, f2_2, f2_4, f2_5, f2_6, f2_7, f2_8, f3_1, f3_2, f3_3, f4, f4_1,
# f4_10, f4_11, f4_13, f4_14, f4_16, f4_17, f4_18, f4_2, f4_3, f4_5, f4_6, f4_7, f4_8,
# f4_9, f5, f5_1, f5_3, f5_4, f6, f6_1, f6_2, f6_4, f7, f8, f8_1, f8_2,
# f8_3, f8_4, f8_5
# FROM xjk_algo_comp.pois AS pois
# JOIN xjk_algo_comp.districts AS districts ON districts.district_hash = pois.district_hash

# %%
pois_df = bq.Query(q_pois).to_dataframe()

# %% [markdown]
# Create **gaps** table. Each row of this table should contain all features from three previous timeslots.

# %%
class Batch:
  def __init__(self):
    self.district_ids = []
    self.order_gaps_df = None
    self.pois_df = None
    self.pois_fields = []
    self.prev_n_range = 0
    self.traffic_df = None
    self.weather_df = None
    self.prev_timeslots_dict = {}

  def process(self, all_timeslots):
    counter = 0
    gaps_df = pd.DataFrame(columns=columns)
    for timeslot in all_timeslots:
      print 'Now processing timeslot {}'.format(timeslot)
      for district_id in self.district_ids:
        timeslot_r = map(lambda x: int(x), timeslot.split('-'))
        gap_data = {'timeslot': timeslot,
                    'day_in_week': date(timeslot_r[0], timeslot_r[1], timeslot_r[2]).weekday(),
                    'timeofday_slot': timeslot_r[3],
                    'district_id': int(district_id),
                    'gap': int(0)
                   }
        poi_row = self.pois_df.loc[
          (self.pois_df['district_id'] == district_id)
        ]
        for poi_field in self.pois_fields:
          gap_data[poi_field] = poi_row.iloc[0][poi_field]
        prev_gaps = self.order_gaps_df.loc[
          (self.order_gaps_df['timeslot'].isin(self.prev_timeslots_dict[timeslot])) &
          (self.order_gaps_df['district_id'] == district_id)
        ]

        for i in range(self.prev_n_range+1):
          slot_diff = i
          past_timeslot = calc_past_timeslot(timeslot, slot_diff)
          prev_gap_loc = prev_gaps.loc[
            prev_gaps['timeslot'] == past_timeslot
          ]
          if not prev_gap_loc.empty:
            prev_gap = prev_gap_loc.iloc[0]
            if prev_gap['timeslot'] == timeslot:
              gap_data['gap'] = int(prev_gap['gap'])
            else:
              gap_data['gap_{}_slots_ago'.format(slot_diff)] = int(prev_gap['gap'])
              gap_data['sum_price_{}_slots_ago'.format(slot_diff)] = prev_gap['sum_price']

          if slot_diff > 0:
            # There is a possibility that weather or traffic for previous
            # slot does not get recorded, which means we need to get
            # average weather conditions for other existing slots.

            traffic_row = self.traffic_df.loc[
              (self.traffic_df['timeslot'] == past_timeslot) &
              (self.traffic_df['district_id'] == district_id)
            ]
            if not traffic_row.empty:
              gap_data['tj_level1_{}_slots_ago'.format(slot_diff)] = traffic_row.iloc[0]['tj_level1']
              gap_data['tj_level2_{}_slots_ago'.format(slot_diff)] = traffic_row.iloc[0]['tj_level2']
              gap_data['tj_level3_{}_slots_ago'.format(slot_diff)] = traffic_row.iloc[0]['tj_level3']
              gap_data['tj_level4_{}_slots_ago'.format(slot_diff)] = traffic_row.iloc[0]['tj_level4']
            else:
              # Traffic row is empty, lets get average of other three traffic rows
              traffic_rows = self.traffic_df.loc[
                (self.traffic_df['timeslot'].isin(self.prev_timeslots_dict[timeslot])) &
                (self.traffic_df['district_id'] == district_id)
              ]
              gap_data['tj_level1_{}_slots_ago'.format(slot_diff)] = traffic_rows['tj_level1'].mean()
              gap_data['tj_level2_{}_slots_ago'.format(slot_diff)] = traffic_rows['tj_level2'].mean()
              gap_data['tj_level3_{}_slots_ago'.format(slot_diff)] = traffic_rows['tj_level3'].mean()
              gap_data['tj_level4_{}_slots_ago'.format(slot_diff)] = traffic_rows['tj_level4'].mean()

            weather_row = self.weather_df.loc[
              (self.weather_df['timeslot']==past_timeslot)
            ]
            if not weather_row.empty:
              gap_data['weather_{}_slots_ago'.format(slot_diff)] = weather_row.iloc[0]['weather']
              gap_data['temperature_{}_slots_ago'.format(slot_diff)] = weather_row.iloc[0]['temperature']
              gap_data['pm25_{}_slots_ago'.format(slot_diff)] = weather_row.iloc[0]['pm25']
            else:
              # Weather row is empty, lets get average of other three weather rows
              weather_rows = self.weather_df.loc[
                (self.weather_df['timeslot'].isin(self.prev_timeslots_dict[timeslot]))
              ]
              gap_data['weather_{}_slots_ago'.format(slot_diff)] = weather_rows['weather'].mean()
              gap_data['temperature_{}_slots_ago'.format(slot_diff)] = weather_rows['temperature'].mean()
              gap_data['pm25_{}_slots_ago'.format(slot_diff)] = weather_rows['pm25'].mean()

        gaps_df = gaps_df.append(gap_data, ignore_index=True)
        counter += 1
        if counter % 100 == 0:
          print 'created {} rows'.format(counter)
    gaps_df['district_id'] = gaps_df['district_id'].astype('int64')
    return gaps_df

# %%
# %%sql --module q_districts
#
# SELECT district_id
# FROM xjk_algo_comp.districts
# ORDER BY district_id

# %%
# Initialize batches
batch_size = 10
config_file = 'batch_pos.txt'

district_ids = [item['district_id'] for item in bq.Query(q_districts).results()]

if not os.path.isfile(config_file):
  with open(config_file, 'wb') as f:
    f.write('0')

# %%
with open(config_file, 'rb') as f:
  batch_pos = int(f.read())
  
total_batches = len(all_timeslots) / batch_size
leftover = (len(all_timeslots) - batch_pos) % batch_size

gaps_table = bq.Table('datalab-projects-1331:xjk_algo_comp.gaps')
if not gaps_table.exists():
  schema = []
  for index, column in enumerate(columns):
    if index == 0:
      schema.append({'name': column, 'type': 'INTEGER'})
    elif index == 1:
      schema.append({'name': column, 'type': 'STRING'})
    else:
      schema.append({'name': column, 'type': 'FLOAT'})
  gaps_table.create(bq.Schema(schema))

batch = Batch()
batch.district_ids = district_ids
batch.order_gaps_df = order_gaps_df
batch.pois_df = pois_df
batch.pois_fields = pois_fields
batch.prev_n_range = prev_n_range
batch.traffic_df = traffic_df
batch.weather_df = weather_df
batch.prev_timeslots_dict = prev_timeslots_dict

for i in range(batch_pos, total_batches+1):
  print "Starting batch pos: {}".format(i)
  from_pos = i*batch_size
  to_pos = (i+1)*batch_size
  if to_pos >= len(all_timeslots):
    to_pos = len(all_timeslots)
  timeslots_to_process = all_timeslots[from_pos:to_pos]
  print 'Writing timeslots from {}({}) to {}({}) ({} rows)'.format(
    timeslots_to_process[0],
    from_pos,
    timeslots_to_process[len(timeslots_to_process)-1],
    to_pos,
    (to_pos-from_pos)*len(district_ids)
  )
  gaps_df = batch.process(timeslots_to_process)
  gaps_table.insert_data(gaps_df)
  print '{} rows committed into database'.format(len(gaps_df))
  with open(config_file, 'wb') as f:
    f.write(str(i+1))
# Out:
# Starting batch pos: 131
# Writing timeslots from 2016-01-10-18(1310) to 2016-01-10-27(1320) (660 rows)
# Now processing timeslot 2016-01-10-18
# Now processing timeslot 2016-01-10-19
# created 100 rows
# Now processing timeslot 2016-01-10-20
# Now processing timeslot 2016-01-10-21
# created 200 rows
# Now processing timeslot 2016-01-10-22
# created 300 rows
# Now processing timeslot 2016-01-10-23
# Now processing timeslot 2016-01-10-24
# created 400 rows
# Now processing timeslot 2016-01-10-25
# created 500 rows
# Now processing timeslot 2016-01-10-26
# Now processing timeslot 2016-01-10-27
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 132
# Writing timeslots from 2016-01-10-28(1320) to 2016-01-10-37(1330) (660 rows)
# Now processing timeslot 2016-01-10-28
# Now processing timeslot 2016-01-10-29
# created 100 rows
# Now processing timeslot 2016-01-10-30
# Now processing timeslot 2016-01-10-31
# created 200 rows
# Now processing timeslot 2016-01-10-32
# created 300 rows
# Now processing timeslot 2016-01-10-33
# Now processing timeslot 2016-01-10-34
# created 400 rows
# Now processing timeslot 2016-01-10-35
# created 500 rows
# Now processing timeslot 2016-01-10-36
# Now processing timeslot 2016-01-10-37
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 133
# Writing timeslots from 2016-01-10-38(1330) to 2016-01-10-47(1340) (660 rows)
# Now processing timeslot 2016-01-10-38
# Now processing timeslot 2016-01-10-39
# created 100 rows
# Now processing timeslot 2016-01-10-40
# Now processing timeslot 2016-01-10-41
# created 200 rows
# Now processing timeslot 2016-01-10-42
# created 300 rows
# Now processing timeslot 2016-01-10-43
# Now processing timeslot 2016-01-10-44
# created 400 rows
# Now processing timeslot 2016-01-10-45
# created 500 rows
# Now processing timeslot 2016-01-10-46
# Now processing timeslot 2016-01-10-47
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 134
# Writing timeslots from 2016-01-10-48(1340) to 2016-01-10-57(1350) (660 rows)
# Now processing timeslot 2016-01-10-48
# Now processing timeslot 2016-01-10-49
# created 100 rows
# Now processing timeslot 2016-01-10-50
# Now processing timeslot 2016-01-10-51
# created 200 rows
# Now processing timeslot 2016-01-10-52
# created 300 rows
# Now processing timeslot 2016-01-10-53
# Now processing timeslot 2016-01-10-54
# created 400 rows
# Now processing timeslot 2016-01-10-55
# created 500 rows
# Now processing timeslot 2016-01-10-56
# Now processing timeslot 2016-01-10-57
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 135
# Writing timeslots from 2016-01-10-58(1350) to 2016-01-10-67(1360) (660 rows)
# Now processing timeslot 2016-01-10-58
# Now processing timeslot 2016-01-10-59
# created 100 rows
# Now processing timeslot 2016-01-10-60
# Now processing timeslot 2016-01-10-61
# created 200 rows
# Now processing timeslot 2016-01-10-62
# created 300 rows
# Now processing timeslot 2016-01-10-63
# Now processing timeslot 2016-01-10-64
# created 400 rows
# Now processing timeslot 2016-01-10-65
# created 500 rows
# Now processing timeslot 2016-01-10-66
# Now processing timeslot 2016-01-10-67
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 136
# Writing timeslots from 2016-01-10-68(1360) to 2016-01-10-77(1370) (660 rows)
# Now processing timeslot 2016-01-10-68
# Now processing timeslot 2016-01-10-69
# created 100 rows
# Now processing timeslot 2016-01-10-70
# Now processing timeslot 2016-01-10-71
# created 200 rows
# Now processing timeslot 2016-01-10-72
# created 300 rows
# Now processing timeslot 2016-01-10-73
# Now processing timeslot 2016-01-10-74
# created 400 rows
# Now processing timeslot 2016-01-10-75
# created 500 rows
# Now processing timeslot 2016-01-10-76
# Now processing timeslot 2016-01-10-77
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 137
# Writing timeslots from 2016-01-10-78(1370) to 2016-01-10-87(1380) (660 rows)
# Now processing timeslot 2016-01-10-78
# Now processing timeslot 2016-01-10-79
# created 100 rows
# Now processing timeslot 2016-01-10-80
# Now processing timeslot 2016-01-10-81
# created 200 rows
# Now processing timeslot 2016-01-10-82
# created 300 rows
# Now processing timeslot 2016-01-10-83
# Now processing timeslot 2016-01-10-84
# created 400 rows
# Now processing timeslot 2016-01-10-85
# created 500 rows
# Now processing timeslot 2016-01-10-86
# Now processing timeslot 2016-01-10-87
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 138
# Writing timeslots from 2016-01-10-88(1380) to 2016-01-10-97(1390) (660 rows)
# Now processing timeslot 2016-01-10-88
# Now processing timeslot 2016-01-10-89
# created 100 rows
# Now processing timeslot 2016-01-10-90
# Now processing timeslot 2016-01-10-91
# created 200 rows
# Now processing timeslot 2016-01-10-92
# created 300 rows
# Now processing timeslot 2016-01-10-93
# Now processing timeslot 2016-01-10-94
# created 400 rows
# Now processing timeslot 2016-01-10-95
# created 500 rows
# Now processing timeslot 2016-01-10-96
# Now processing timeslot 2016-01-10-97
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 139
# Writing timeslots from 2016-01-10-98(1390) to 2016-01-10-107(1400) (660 rows)
# Now processing timeslot 2016-01-10-98
# Now processing timeslot 2016-01-10-99
# created 100 rows
# Now processing timeslot 2016-01-10-100
# Now processing timeslot 2016-01-10-101
# created 200 rows
# Now processing timeslot 2016-01-10-102
# created 300 rows
# Now processing timeslot 2016-01-10-103
# Now processing timeslot 2016-01-10-104
# created 400 rows
# Now processing timeslot 2016-01-10-105
# created 500 rows
# Now processing timeslot 2016-01-10-106
# Now processing timeslot 2016-01-10-107
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 140
# Writing timeslots from 2016-01-10-108(1400) to 2016-01-10-117(1410) (660 rows)
# Now processing timeslot 2016-01-10-108
# Now processing timeslot 2016-01-10-109
# created 100 rows
# Now processing timeslot 2016-01-10-110
# Now processing timeslot 2016-01-10-111
# created 200 rows
# Now processing timeslot 2016-01-10-112
# created 300 rows
# Now processing timeslot 2016-01-10-113
# Now processing timeslot 2016-01-10-114
# created 400 rows
# Now processing timeslot 2016-01-10-115
# created 500 rows
# Now processing timeslot 2016-01-10-116
# Now processing timeslot 2016-01-10-117
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 141
# Writing timeslots from 2016-01-10-118(1410) to 2016-01-10-127(1420) (660 rows)
# Now processing timeslot 2016-01-10-118
# Now processing timeslot 2016-01-10-119
# created 100 rows
# Now processing timeslot 2016-01-10-120
# Now processing timeslot 2016-01-10-121
# created 200 rows
# Now processing timeslot 2016-01-10-122
# created 300 rows
# Now processing timeslot 2016-01-10-123
# Now processing timeslot 2016-01-10-124
# created 400 rows
# Now processing timeslot 2016-01-10-125
# created 500 rows
# Now processing timeslot 2016-01-10-126
# Now processing timeslot 2016-01-10-127
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 142
# Writing timeslots from 2016-01-10-128(1420) to 2016-01-10-137(1430) (660 rows)
# Now processing timeslot 2016-01-10-128
# Now processing timeslot 2016-01-10-129
# created 100 rows
# Now processing timeslot 2016-01-10-130
# Now processing timeslot 2016-01-10-131
# created 200 rows
# Now processing timeslot 2016-01-10-132
# created 300 rows
# Now processing timeslot 2016-01-10-133
# Now processing timeslot 2016-01-10-134
# created 400 rows
# Now processing timeslot 2016-01-10-135
# created 500 rows
# Now processing timeslot 2016-01-10-136
# Now processing timeslot 2016-01-10-137
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 143
# Writing timeslots from 2016-01-10-138(1430) to 2016-01-11-3(1440) (660 rows)
# Now processing timeslot 2016-01-10-138
# Now processing timeslot 2016-01-10-139
# created 100 rows
# Now processing timeslot 2016-01-10-140
# Now processing timeslot 2016-01-10-141
# created 200 rows
# Now processing timeslot 2016-01-10-142
# created 300 rows
# Now processing timeslot 2016-01-10-143
# Now processing timeslot 2016-01-10-144
# created 400 rows
# Now processing timeslot 2016-01-11-1
# created 500 rows
# Now processing timeslot 2016-01-11-2
# Now processing timeslot 2016-01-11-3
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 144
# Writing timeslots from 2016-01-11-4(1440) to 2016-01-11-13(1450) (660 rows)
# Now processing timeslot 2016-01-11-4
# Now processing timeslot 2016-01-11-5
# created 100 rows
# Now processing timeslot 2016-01-11-6
# Now processing timeslot 2016-01-11-7
# created 200 rows
# Now processing timeslot 2016-01-11-8
# created 300 rows
# Now processing timeslot 2016-01-11-9
# Now processing timeslot 2016-01-11-10
# created 400 rows
# Now processing timeslot 2016-01-11-11
# created 500 rows
# Now processing timeslot 2016-01-11-12
# Now processing timeslot 2016-01-11-13
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 145
# Writing timeslots from 2016-01-11-14(1450) to 2016-01-11-23(1460) (660 rows)
# Now processing timeslot 2016-01-11-14
# Now processing timeslot 2016-01-11-15
# created 100 rows
# Now processing timeslot 2016-01-11-16
# Now processing timeslot 2016-01-11-17
# created 200 rows
# Now processing timeslot 2016-01-11-18
# created 300 rows
# Now processing timeslot 2016-01-11-19
# Now processing timeslot 2016-01-11-20
# created 400 rows
# Now processing timeslot 2016-01-11-21
# created 500 rows
# Now processing timeslot 2016-01-11-22
# Now processing timeslot 2016-01-11-23
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 146
# Writing timeslots from 2016-01-11-24(1460) to 2016-01-11-33(1470) (660 rows)
# Now processing timeslot 2016-01-11-24
# Now processing timeslot 2016-01-11-25
# created 100 rows
# Now processing timeslot 2016-01-11-26
# Now processing timeslot 2016-01-11-27
# created 200 rows
# Now processing timeslot 2016-01-11-28
# created 300 rows
# Now processing timeslot 2016-01-11-29
# Now processing timeslot 2016-01-11-30
# created 400 rows
# Now processing timeslot 2016-01-11-31
# created 500 rows
# Now processing timeslot 2016-01-11-32
# Now processing timeslot 2016-01-11-33
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 147
# Writing timeslots from 2016-01-11-34(1470) to 2016-01-11-43(1480) (660 rows)
# Now processing timeslot 2016-01-11-34
# Now processing timeslot 2016-01-11-35
# created 100 rows
# Now processing timeslot 2016-01-11-36
# Now processing timeslot 2016-01-11-37
# created 200 rows
# Now processing timeslot 2016-01-11-38
# created 300 rows
# Now processing timeslot 2016-01-11-39
# Now processing timeslot 2016-01-11-40
# created 400 rows
# Now processing timeslot 2016-01-11-41
# created 500 rows
# Now processing timeslot 2016-01-11-42
# Now processing timeslot 2016-01-11-43
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 148
# Writing timeslots from 2016-01-11-44(1480) to 2016-01-11-53(1490) (660 rows)
# Now processing timeslot 2016-01-11-44
# Now processing timeslot 2016-01-11-45
# created 100 rows
# Now processing timeslot 2016-01-11-46
# Now processing timeslot 2016-01-11-47
# created 200 rows
# Now processing timeslot 2016-01-11-48
# created 300 rows
# Now processing timeslot 2016-01-11-49
# Now processing timeslot 2016-01-11-50
# created 400 rows
# Now processing timeslot 2016-01-11-51
# created 500 rows
# Now processing timeslot 2016-01-11-52
# Now processing timeslot 2016-01-11-53
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 149
# Writing timeslots from 2016-01-11-54(1490) to 2016-01-11-63(1500) (660 rows)
# Now processing timeslot 2016-01-11-54
# Now processing timeslot 2016-01-11-55
# created 100 rows
# Now processing timeslot 2016-01-11-56
# Now processing timeslot 2016-01-11-57
# created 200 rows
# Now processing timeslot 2016-01-11-58
# created 300 rows
# Now processing timeslot 2016-01-11-59
# Now processing timeslot 2016-01-11-60
# created 400 rows
# Now processing timeslot 2016-01-11-61
# created 500 rows
# Now processing timeslot 2016-01-11-62
# Now processing timeslot 2016-01-11-63
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 150
# Writing timeslots from 2016-01-11-64(1500) to 2016-01-11-73(1510) (660 rows)
# Now processing timeslot 2016-01-11-64
# Now processing timeslot 2016-01-11-65
# created 100 rows
# Now processing timeslot 2016-01-11-66
# Now processing timeslot 2016-01-11-67
# created 200 rows
# Now processing timeslot 2016-01-11-68
# created 300 rows
# Now processing timeslot 2016-01-11-69
# Now processing timeslot 2016-01-11-70
# created 400 rows
# Now processing timeslot 2016-01-11-71
# created 500 rows
# Now processing timeslot 2016-01-11-72
# Now processing timeslot 2016-01-11-73
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 151
# Writing timeslots from 2016-01-11-74(1510) to 2016-01-11-83(1520) (660 rows)
# Now processing timeslot 2016-01-11-74
# Now processing timeslot 2016-01-11-75
# created 100 rows
# Now processing timeslot 2016-01-11-76
# Now processing timeslot 2016-01-11-77
# created 200 rows
# Now processing timeslot 2016-01-11-78
# created 300 rows
# Now processing timeslot 2016-01-11-79
# Now processing timeslot 2016-01-11-80
# created 400 rows
# Now processing timeslot 2016-01-11-81
# created 500 rows
# Now processing timeslot 2016-01-11-82
# Now processing timeslot 2016-01-11-83
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 152
# Writing timeslots from 2016-01-11-84(1520) to 2016-01-11-93(1530) (660 rows)
# Now processing timeslot 2016-01-11-84
# Now processing timeslot 2016-01-11-85
# created 100 rows
# Now processing timeslot 2016-01-11-86
# Now processing timeslot 2016-01-11-87
# created 200 rows
# Now processing timeslot 2016-01-11-88
# created 300 rows
# Now processing timeslot 2016-01-11-89
# Now processing timeslot 2016-01-11-90
# created 400 rows
# Now processing timeslot 2016-01-11-91
# created 500 rows
# Now processing timeslot 2016-01-11-92
# Now processing timeslot 2016-01-11-93
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 153
# Writing timeslots from 2016-01-11-94(1530) to 2016-01-11-103(1540) (660 rows)
# Now processing timeslot 2016-01-11-94
# Now processing timeslot 2016-01-11-95
# created 100 rows
# Now processing timeslot 2016-01-11-96
# Now processing timeslot 2016-01-11-97
# created 200 rows
# Now processing timeslot 2016-01-11-98
# created 300 rows
# Now processing timeslot 2016-01-11-99
# Now processing timeslot 2016-01-11-100
# created 400 rows
# Now processing timeslot 2016-01-11-101
# created 500 rows
# Now processing timeslot 2016-01-11-102
# Now processing timeslot 2016-01-11-103
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 154
# Writing timeslots from 2016-01-11-104(1540) to 2016-01-11-113(1550) (660 rows)
# Now processing timeslot 2016-01-11-104
# Now processing timeslot 2016-01-11-105
# created 100 rows
# Now processing timeslot 2016-01-11-106
# Now processing timeslot 2016-01-11-107
# created 200 rows
# Now processing timeslot 2016-01-11-108
# created 300 rows
# Now processing timeslot 2016-01-11-109
# Now processing timeslot 2016-01-11-110
# created 400 rows
# Now processing timeslot 2016-01-11-111
# created 500 rows
# Now processing timeslot 2016-01-11-112
# Now processing timeslot 2016-01-11-113
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 155
# Writing timeslots from 2016-01-11-114(1550) to 2016-01-11-123(1560) (660 rows)
# Now processing timeslot 2016-01-11-114
# Now processing timeslot 2016-01-11-115
# created 100 rows
# Now processing timeslot 2016-01-11-116
# Now processing timeslot 2016-01-11-117
# created 200 rows
# Now processing timeslot 2016-01-11-118
# created 300 rows
# Now processing timeslot 2016-01-11-119
# Now processing timeslot 2016-01-11-120
# created 400 rows
# Now processing timeslot 2016-01-11-121
# created 500 rows
# Now processing timeslot 2016-01-11-122
# Now processing timeslot 2016-01-11-123
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 156
# Writing timeslots from 2016-01-11-124(1560) to 2016-01-11-133(1570) (660 rows)
# Now processing timeslot 2016-01-11-124
# Now processing timeslot 2016-01-11-125
# created 100 rows
# Now processing timeslot 2016-01-11-126
# Now processing timeslot 2016-01-11-127
# created 200 rows
# Now processing timeslot 2016-01-11-128
# created 300 rows
# Now processing timeslot 2016-01-11-129
# Now processing timeslot 2016-01-11-130
# created 400 rows
# Now processing timeslot 2016-01-11-131
# created 500 rows
# Now processing timeslot 2016-01-11-132
# Now processing timeslot 2016-01-11-133
# created 600 rows
# 660 rows committed into database
# Starting batch pos:
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 173
# Writing timeslots from 2016-01-13-6(1730) to 2016-01-13-15(1740) (660 rows)
# Now processing timeslot 2016-01-13-6
# Now processing timeslot 2016-01-13-7
# created 100 rows
# Now processing timeslot 2016-01-13-8
# Now processing timeslot 2016-01-13-9
# created 200 rows
# Now processing timeslot 2016-01-13-10
# created 300 rows
# Now processing timeslot 2016-01-13-11
# Now processing timeslot 2016-01-13-12
# created 400 rows
# Now processing timeslot 2016-01-13-13
# created 500 rows
# Now processing timeslot 2016-01-13-14
# Now processing timeslot 2016-01-13-15
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 174
# Writing timeslots from 2016-01-13-16(1740) to 2016-01-13-25(1750) (660 rows)
# Now processing timeslot 2016-01-13-16
# Now processing timeslot 2016-01-13-17
# created 100 rows
# Now processing timeslot 2016-01-13-18
# Now processing timeslot 2016-01-13-19
# created 200 rows
# Now processing timeslot 2016-01-13-20
# created 300 rows
# Now processing timeslot 2016-01-13-21
# Now processing timeslot 2016-01-13-22
# created 400 rows
# Now processing timeslot 2016-01-13-23
# created 500 rows
# Now processing timeslot 2016-01-13-24
# Now processing timeslot 2016-01-13-25
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 175
# Writing timeslots from 2016-01-13-26(1750) to 2016-01-13-35(1760) (660 rows)
# Now processing timeslot 2016-01-13-26
# Now processing timeslot 2016-01-13-27
# created 100 rows
# Now processing timeslot 2016-01-13-28
# Now processing timeslot 2016-01-13-29
# created 200 rows
# Now processing timeslot 2016-01-13-30
# created 300 rows
# Now processing timeslot 2016-01-13-31
# Now processing timeslot 2016-01-13-32
# created 400 rows
# Now processing timeslot 2016-01-13-33
# created 500 rows
# Now processing timeslot 2016-01-13-34
# Now processing timeslot 2016-01-13-35
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 176
# Writing timeslots from 2016-01-13-36(1760) to 2016-01-13-45(1770) (660 rows)
# Now processing timeslot 2016-01-13-36
# Now processing timeslot 2016-01-13-37
# created 100 rows
# Now processing timeslot 2016-01-13-38
# Now processing timeslot 2016-01-13-39
# created 200 rows
# Now processing timeslot 2016-01-13-40
# created 300 rows
# Now processing timeslot 2016-01-13-41
# Now processing timeslot 2016-01-13-42
# created 400 rows
# Now processing timeslot 2016-01-13-43
# created 500 rows
# Now processing timeslot 2016-01-13-44
# Now processing timeslot 2016-01-13-45
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 177
# Writing timeslots from 2016-01-13-46(1770) to 2016-01-13-55(1780) (660 rows)
# Now processing timeslot 2016-01-13-46
# Now processing timeslot 2016-01-13-47
# created 100 rows
# Now processing timeslot 2016-01-13-48
# Now processing timeslot 2016-01-13-49
# created 200 rows
# Now processing timeslot 2016-01-13-50
# created 300 rows
# Now processing timeslot 2016-01-13-51
# Now processing timeslot 2016-01-13-52
# created 400 rows
# Now processing timeslot 2016-01-13-53
# created 500 rows
# Now processing timeslot 2016-01-13-54
# Now processing timeslot 2016-01-13-55
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 178
# Writing timeslots from 2016-01-13-56(1780) to 2016-01-13-65(1790) (660 rows)
# Now processing timeslot 2016-01-13-56
# Now processing timeslot 2016-01-13-57
# created 100 rows
# Now processing timeslot 2016-01-13-58
# Now processing timeslot 2016-01-13-59
# created 200 rows
# Now processing timeslot 2016-01-13-60
# created 300 rows
# Now processing timeslot 2016-01-13-61
# Now processing timeslot 2016-01-13-62
# created 400 rows
# Now processing timeslot 2016-01-13-63
# created 500 rows
# Now processing timeslot 2016-01-13-64
# Now processing timeslot 2016-01-13-65
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 179
# Writing timeslots from 2016-01-13-66(1790) to 2016-01-13-75(1800) (660 rows)
# Now processing timeslot 2016-01-13-66
# Now processing timeslot 2016-01-13-67
# created 100 rows
# Now processing timeslot 2016-01-13-68
# Now processing timeslot 2016-01-13-69
# created 200 rows
# Now processing timeslot 2016-01-13-70
# created 300 rows
# Now processing timeslot 2016-01-13-71
# Now processing timeslot 2016-01-13-72
# created 400 rows
# Now processing timeslot 2016-01-13-73
# created 500 rows
# Now processing timeslot 2016-01-13-74
# Now processing timeslot 2016-01-13-75
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 180
# Writing timeslots from 2016-01-13-76(1800) to 2016-01-13-85(1810) (660 rows)
# Now processing timeslot 2016-01-13-76
# Now processing timeslot 2016-01-13-77
# created 100 rows
# Now processing timeslot 2016-01-13-78
# Now processing timeslot 2016-01-13-79
# created 200 rows
# Now processing timeslot 2016-01-13-80
# created 300 rows
# Now processing timeslot 2016-01-13-81
# Now processing timeslot 2016-01-13-82
# created 400 rows
# Now processing timeslot 2016-01-13-83
# created 500 rows
# Now processing timeslot 2016-01-13-84
# Now processing timeslot 2016-01-13-85
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 181
# Writing timeslots from 2016-01-13-86(1810) to 2016-01-13-95(1820) (660 rows)
# Now processing timeslot 2016-01-13-86
# Now processing timeslot 2016-01-13-87
# created 100 rows
# Now processing timeslot 2016-01-13-88
# Now processing timeslot 2016-01-13-89
# created 200 rows
# Now processing timeslot 2016-01-13-90
# created 300 rows
# Now processing timeslot 2016-01-13-91
# Now processing timeslot 2016-01-13-92
# created 400 rows
# Now processing timeslot 2016-01-13-93
# created 500 rows
# Now processing timeslot 2016-01-13-94
# Now processing timeslot 2016-01-13-95
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 182
# Writing timeslots from 2016-01-13-96(1820) to 2016-01-13-105(1830) (660 rows)
# Now processing timeslot 2016-01-13-96
# Now processing timeslot 2016-01-13-97
# created 100 rows
# Now processing timeslot 2016-01-13-98
# Now processing timeslot 2016-01-13-99
# created 200 rows
# Now processing timeslot 2016-01-13-100
# created 300 rows
# Now processing timeslot 2016-01-13-101
# Now processing timeslot 2016-01-13-102
# created 400 rows
# Now processing timeslot 2016-01-13-103
# created 500 rows
# Now processing timeslot 2016-01-13-104
# Now processing timeslot 2016-01-13-105
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 183
# Writing timeslots from 2016-01-13-106(1830) to 2016-01-13-115(1840) (660 rows)
# Now processing timeslot 2016-01-13-106
# Now processing timeslot 2016-01-13-107
# created 100 rows
# Now processing timeslot 2016-01-13-108
# Now processing timeslot 2016-01-13-109
# created 200 rows
# Now processing timeslot 2016-01-13-110
# created 300 rows
# Now processing timeslot 2016-01-13-111
# Now processing timeslot 2016-01-13-112
# created 400 rows
# Now processing timeslot 2016-01-13-113
# created 500 rows
# Now processing timeslot 2016-01-13-114
# Now processing timeslot 2016-01-13-115
# created 600 rows
# 660 rows committed into database
# Starting batch pos: 184
# Writing timeslots from 2016-01-13-116(1840) to 2016-01-13-125(1850) (660 rows)
# Now processing timeslot 2016-01-13-116
# Now processing timeslot 2016-01-13-117
# created 100 rows
# Now processing timeslot 2016-01-13-118
# Now processing timeslot 2016-01-13-119
# created 200 rows
# Now processing timeslot 2016-01-13-120
